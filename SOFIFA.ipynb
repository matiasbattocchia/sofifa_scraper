# %%
import datetime
import requests
from scrapy.http import TextResponse

# %%
import re

def text_cleaner(text):
    return [item.strip() for item in text if not re.match('^(\r\n|\s)+$', item)]

# %%
def money(value):
    
    quantity, multiplier = re.search('([\d\.]+)(M|K)?', value).groups()
    quantity = float(quantity)
    
    if multiplier:
        multiplier = {'M':1000000, 'K':1000}[multiplier]
    else:
        multiplier = 1
    
    return int(quantity * multiplier)

# %% [markdown]
# ## Teams

# %%
#r = requests.get('https://sofifa.com/team/112791')
#response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
#team = {}
#team_basic(response, team)
#team_stats(response, team)
#team_lineup(response, team)
#team_info(response, team)
#team

# %%
def team_basic(response, team):
    raw   = response.css('div.info').xpath('.//text()').extract()
    clean = text_cleaner(raw)

    team['Name'], team['Team ID'] = re.match('([\w\s\.\-\'\(\)\&]+) \(ID: (\d+)\)', clean[0]).groups()
    team['League'] = clean[1]
    team['Nationality'] = response.css('div.info').xpath('.//a[contains(@href, "teams?na=")]/@title').extract_first()

# %%
def team_lineup(response, team):
    team['Lineup'] = []

    for position in response.xpath('.//div[@class="field-player"]'):
        pos = {}
 
        y, x = position.xpath('./@style').re('top:([\d\.\-]+)px;left:([\d\.\-]+)px;')
        
        pos['Player ID']   = position.xpath('./a/@href').re_first('\d+')
        pos['y'], pos['x'] = float(y), float(x)
        
        rows = position.xpath('.//span[@class="nowrap row"]')

        if len(rows) == 0:
            pos['Position'] = 'GK'
        else:
            pos['Instructions'] = {}

            for row in rows:
                instruction, value = text_cleaner(row.xpath('.//text()').extract())

                if re.search('instructions', value, re.IGNORECASE):
                    pos['Position'] = instruction
                else:
                    pos['Instructions'][instruction] = value.lower()

        team['Lineup'].append(pos)

# %%
def team_stats(response, team):
    extract = lambda stat: response.xpath('//span[contains(.., $concept)]/text()', concept=stat).extract_first()

    stats = ['Overall', 'Attack', 'Midfield', 'Defence']

    for stat in stats:
        team[stat] = int(extract(stat))

# %%
def team_info(response, team):
     
    raw = response.xpath('//li[contains(label, "Home stadium")]/text()').extract()
    team['Home stadium'] = text_cleaner(raw)[0]
    
    raw = response.xpath('//li[contains(label, "Transfer budget")]/text()').extract()
    
    if raw:
        team['Transfer budget €'] = money(text_cleaner(raw)[0])

    for concept in ['Starting 11 average age', 'Whole team average age']:
        raw = response.xpath('//li[contains(label, $concept)]/text()', concept=concept).extract()
        team[concept] = float(text_cleaner(raw)[0])
        
    for concept in ['International prestige', 'Domestic prestige']:
        raw = response.xpath('//li[contains(label, $concept)]/span/text()', concept=concept).extract_first()
        if raw:
            team[concept] = int(raw)
        
    for concept in ['Rival team', 'Captain', 'Short free kick', 'Long free kick', 'Penalties', 'Left corner', 'Right corner']:
        team[concept + ' ID'] = response.xpath('//li[contains(label, $concept)]/a/@href', concept=concept).re_first('\d+')

# %% [markdown]
# ## Players

# %%
#r = requests.get('https://sofifa.com/player/232171')
#response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
#player = {}
#basic(response, player)
#stats(response, player)
#body(response, player)
#composed_attributes(response, player)
#teams(response, player)
#attributes(response, player)
#traits_and_specialities(response, player)
#player

# %% [markdown]
# ### Header — Basic info

# %%
def basic(response, player):
    
    # 'Known as'
    # 'Player ID'
    # 'Name'
    # 'Nationality' 
    # 'Positions'
    # 'Birth date'
    # 'Height [cm]'
    # 'Weight [kg]'

    raw   = response.css('div.info').xpath('.//text()').extract()
    clean = text_cleaner(raw)

    player['Known as'], player['Player ID'] = re.match('([\w\s\.\-\']+) \(ID: (\d+)\)', clean[0]).groups()
    player['Name'] = clean[1]
    player['Positions'] = {}
    
    for position in clean[2:-1]:
        player['Positions'][position] = True

    match = re.match('Age (\d+) \((\w{3} \d{1,2}, \d{4})\) (\d{3})cm (\d{2,3})kg', clean[-1]) 
    
    player['Age']        = int(match.group(1))
    player['Birth date'] = datetime.datetime.strptime(match.group(2), '%b %d, %Y').strftime('%Y-%m-%d')
    player['Height cm']  = int(match.group(3))
    player['Weight kg']  = int(match.group(4))
    
    player['Nationality'] = response.css('div.info').xpath('.//a[contains(@href, "players?na=")]/@title').extract_first()

# %% [markdown]
# ### Subheader — Stats

# %%
def stats(response, player):
    
    # 'Overall rating'
    # 'Potential'
    # 'Value'
    # 'Wage'
    
    extract = lambda stat: response.xpath('//span[contains(.., $concept)]/text()', concept=stat).extract_first()
       
    player['Overall rating'] = int(  extract('Overall rating'))
    player['Potential']      = int(  extract('Potential'))
    player['Value €']        = money(extract('Value'))
    player['Wage €']         = money(extract('Wage'))

# %% [markdown]
# ### First column — Body

# %%
def body(response, player):
    
    extract = lambda concept: response.xpath('//li[contains(., $concept)]', concept=concept).xpath('(./span|.)/text()').extract()
        
    for concept in ['International reputation', 'Weak foot', 'Skill moves']:
        raw = extract(concept)
        
        if len(raw) == 0: continue
            
        player[concept] = int(text_cleaner(raw)[0])
    
    
    for concept in ['Body type', 'Preferred foot']:
        raw = extract(concept)
        
        if len(raw) == 0: continue
            
        player[concept] = text_cleaner(raw)[0]
        
        
    raw = extract('Work rate')
    
    if len(raw) > 0:
        work_rate = {}
        work_rate['Attacking'], work_rate['Defensive'] = text_cleaner(raw)[0].split(' / ')
        player['Work rate'] = work_rate
    
    
    raw = extract('Release clause')
    
    if len(raw) > 0:
        player['Release clause €'] = money(text_cleaner(raw)[0])

# %% [markdown]
# ### Second column — Composed attributes

# %%
def composed_attributes(response, player):
    raw = response.xpath('//script[contains(text(), "PHY")]/text()').extract_first()
    
    if not raw: return
    
    player['Composed attributes'] = {}
    
    for attribute, value in re.findall('point(\w{3}) = (\d{1,3})', raw):
        player['Composed attributes'][attribute] = int(value)

# %% [markdown]
# ### Third and fourth columns — Teams

# %%
def teams(response, player):
    
    concepts = [
        'Position',
        'Jersey number',
        'Joined',
        'Loaned from',
        'Contract valid until',
    ]
    
    player['Teams'] = {}
    
    for team_column in response.xpath('//a[contains(@href, "team/")]/ancestor::ul'):

        data = {}
        data['Team ID'] = team_column.xpath('.//@href[contains(., "team/")]').re_first('\d+')

        for concept in concepts:
            raw = team_column.xpath('.//li[contains(label, $concept)]', concept=concept) \
                  .xpath('./span | .').xpath('./text() | a/@href').extract()

            if len(raw) == 0: continue

            clean = text_cleaner(raw)[0]

            if   concept == 'Joined':
                data[concept] = datetime.datetime.strptime(clean, '%b %d, %Y').strftime('%Y-%m-%d')
            elif concept == 'Loaned from':
                data[concept] = re.search('\d+', clean).group(0)
            elif concept == 'Contract valid until':
                # this is because in a few cases the date is like "Dec 31, 2017" instead of "2017"
                data[concept] = clean[-4:]
            else:
                data[concept] = clean
            
        if 'Contract valid until' in data: # team type is "club"
            player['Teams']['Club'] = data
        else: # team type is "national"
            player['Teams']['National'] = data

# %% [markdown]
# ### 5th to 7th columns — Attributes

# %%
def attributes(response, player):

    attributes = {
      'Attacking': [
        'Crossing',
        'Finishing',
        'Heading accuracy',
        'Short passing',
        'Volleys',
      ],
      'Skill': [
         'Dribbling',
         'Curve',
         'Free kick accuracy',
         'Long passing',
         'Ball control',
      ],
      'Movement': [
        'Acceleration',
        'Sprint speed',
        'Agility',
        'Reactions',
        'Balance',
      ],
      'Power': [
        'Shot power',
        'Jumping',
        'Stamina',
        'Strength',
        'Long shots',    
      ],
      'Mentality': [
        'Aggression',
        'Interceptions',
        'Positioning',
        'Vision',
        'Penalties',
        'Composure',
      ],
      'Defending': [
        'Marking',
        'Standing tackle',
        'Sliding tackle',
      ],
      'Goalkeeping': [
        'GK diving',
        'GK handling',
        'GK kicking',
        'GK positioning',
        'GK reflexes',
      ],
    }
    
    player['Attributes'] = {}

    for group in attributes:
        player['Attributes'][group] = {}
        
        for attribute in attributes[group]:
            player['Attributes'][group][attribute] = \
                int(response.xpath('//span[contains(.., $concept)]/text()', concept=attribute).extract_first())

# %% [markdown]
# ### 8th column — Traits and specialities

# %%
def traits_and_specialities(response, player):

    for group in ['Traits', 'Specialities']:
        skills = response.xpath('//div[contains(h5, $concept)]/ul/li/text()', concept=group).extract()
        
        if len(skills) == 0: continue
        
        player[group] = {}
        
        for skill in skills:
            player[group][skill] = True

# %% [markdown]
# ## Crawler

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from scrapy.crawler import CrawlerProcess

import logging
import datetime
import scrapy

# %%
class PlayerSpider(scrapy.Spider):
    name = 'Player'
    
    start_urls = [
        'https://sofifa.com/players?units=mks&currency=EUR',
    ]
    
    custom_settings = {
        'LOG_LEVEL':   logging.WARNING,
        'FEED_FORMAT': 'json',
        'FEED_URI':    'players_158904.json'
    }
    
    def parse(self, response):
        # follow links to player pages
        for href in response.xpath('//a[contains(@href, "player/")]/@href'):
            yield response.follow(href, self.parse_player)

        # follow pagination links
        for href in response.xpath('//a[contains(@href, "offset=") and contains(text(), "Next")]/@href'):
            yield response.follow(href, self.parse)      

            
    def parse_player(self, response):
        player = {}

        basic(response, player)
        stats(response, player)
        body(response, player)
        teams(response, player)
        attributes(response, player)
        traits_and_specialities(response, player)

        yield player

# %%
class TeamSpider(scrapy.Spider):
    name = 'Team'
    
    start_urls = [
        'https://sofifa.com/teams/national?units=mks&currency=EUR',
        'https://sofifa.com/teams/club?units=mks&currency=EUR'
    ]
    
    custom_settings = {
        'LOG_LEVEL':   logging.WARNING,
        'FEED_FORMAT': 'json',
        'FEED_URI':    'teams_158904.json'
    }
    
    def parse(self, response):
        # follow links to player pages
        for href in response.xpath('//a[contains(@href, "team/")]/@href'):
            yield response.follow(href, self.parse_team)

        # follow pagination links
        for href in response.xpath('//a[contains(@href, "offset=") and contains(text(), "Next")]/@href'):
            yield response.follow(href, self.parse)      

            
    def parse_team(self, response):
        team = {}

        team_basic(response, team)
        team_stats(response, team)
        team_lineup(response, team)
        team_info(response, team)

        yield team

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(PlayerSpider)
process.start()
# Out:
# 2017-11-12 19:59:33 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-11-12 19:59:33 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}

# %%
import pandas as pd
dfjson = pd.read_json('players_158904.json')
dfjson
# Out:
#        Age                                         Attributes  Birth date  \
# 0       32  {'Movement': {'Acceleration': 89, 'Sprint spee...  1985-02-05
# 1       28  {'Movement': {'Acceleration': 62, 'Sprint spee...  1988-12-16
# 2       31  {'Movement': {'Acceleration': 64, 'Sprint spee...  1986-02-16
# 3       35  {'Movement': {'Acceleration': 63, 'Sprint spee...  1981-10-03
# 4       24  {'Movement': {'Acceleration': 69, 'Sprint spee...  1992-11-05
# 5       31  {'Movement': {'Acceleration': 72, 'Sprint spee...  1986-01-08
# 6       26  {'Movement': {'Acceleration': 82, 'Sprint spee...  1991-03-29
# 7       33  {'Movement': {'Acceleration': 87, 'Sprint spee...  1984-01-23
# 8       32  {'Movement': {'Acceleration': 39, 'Sprint spee...  1984-07-14
# 9       30  {'Movement': {'Acceleration': 65, 'Sprint spee...  1986-12-26
# 10      28  {'Movement': {'Acceleration': 72, 'Sprint spee...  1988-09-03
# 11      30  {'Movement': {'Acceleration': 62, 'Sprint spee...  1987-05-01
# 12      28  {'Movement': {'Acceleration': 95, 'Sprint spee...  1989-06-18
# 13      26  {'Movement': {'Acceleration': 77, 'Sprint spee...  1991-04-11
# 14      26  {'Movement': {'Acceleration': 87, 'Sprint spee...  1991-03-21
# 15      24  {'Movement': {'Acceleration': 43, 'Sprint spee...  1993-01-07
# 16      28  {'Movement': {'Acceleration': 93, 'Sprint spee...  1989-03-21
# 17      25  {'Movement': {'Acceleration': 38, 'Sprint spee...  1992-04-30
# 18      25  {'Movement': {'Acceleration': 46, 'Sprint spee...  1992-03-04
# 19      29  {'Movement': {'Acceleration': 53, 'Sprint spee...  1988-02-03
# 20      32  {'Movement': {'Acceleration': 51, 'Sprint spee...  1984-10-27
# 21      28  {'Movement': {'Acceleration': 88, 'Sprint spee...  1989-01-21
# 22      30  {'Movement': {'Acceleration': 54, 'Sprint spee...  1986-12-15
# 23      26  {'Movement': {'Acceleration': 84, 'Sprint spee...  1991-05-28
# 24      25  {'Movement': {'Acceleration': 74, 'Sprint spee...  1992-01-08
# 25      26  {'Movement': {'Acceleration': 94, 'Sprint spee...  1991-06-04
# 26      25  {'Movement': {'Acceleration': 63, 'Sprint spee...  1992-02-23
# 27      24  {'Movement': {'Acceleration': 80, 'Sprint spee...  1993-04-25
# 28      24  {'Movement': {'Acceleration': 79, 'Sprint spee...  1992-10-23
# 29      35  {'Movement': {'Acceleration': 35, 'Sprint spee...  1982-05-20
# ...    ...                                                ...         ...
# 18011   33  {'Movement': {'Acceleration': 72, 'Sprint spee...  1984-05-11
# 18012   30  {'Movement': {'Acceleration': 55, 'Sprint spee...  1987-02-02
# 18013   32  {'Movement': {'Acceleration': 70, 'Sprint spee...  1984-09-22
# 18014   29  {'Movement': {'Acceleration': 67, 'Sprint spee...  1988-03-10
# 18015   29  {'Movement': {'Acceleration': 72, 'Sprint spee...  1987-07-27
# 18016   29  {'Movement': {'Acceleration': 77, 'Sprint spee...  1988-05-12
# 18017   28  {'Movement': {'Acceleration': 75, 'Sprint spee...  1988-10-15
# 18018   30  {'Movement': {'Acceleration': 75, 'Sprint spee...  1987-02-14
# 18019   25  {'Movement': {'Acceleration': 77, 'Sprint spee...  1992-02-14
# 18020   30  {'Movement': {'Acceleration': 76, 'Sprint spee...  1987-05-22
# 18021   24  {'Movement': {'Acceleration': 72, 'Sprint spee...  1993-03-15
# 18022   23  {'Movement': {'Acceleration': 88, 'Sprint spee...  1993-11-15
# 18023   39  {'Movement': {'Acceleration': 49, 'Sprint spee...  1978-01-28
# 18024   32  {'Movement': {'Acceleration': 68, 'Sprint spee...  1984-08-14
# 18025   29  {'Movement': {'Acceleration': 90, 'Sprint spee...  1988-06-02
# 18026   27  {'Movement': {'Acceleration': 93, 'Sprint spee...  1989-07-16
# 18027   31  {'Movement': {'Acceleration': 75, 'Sprint spee...  1985-09-09
# 18028   28  {'Movement': {'Acceleration': 88, 'Sprint spee...  1988-12-19
# 18029   26  {'Movement': {'Acceleration': 77, 'Sprint spee...  1991-06-28
# 18030   25  {'Movement': {'Acceleration': 46, 'Sprint spee...  1992-05-11
# 18031   29  {'Movement': {'Acceleration': 78, 'Sprint spee...  1987-12-10
# 18032   31  {'Movement': {'Acceleration': 75, 'Sprint spee...  1986-03-30
# 18033   27  {'Movement': {'Acceleration': 60, 'Sprint spee...  1990-01-04
# 18034   26  {'Movement': {'Acceleration': 93, 'Sprint spee...  1991-01-07
# 18035   26  {'Movement': {'Acceleration': 57, 'Sprint spee...  1990-11-07
# 18036   31  {'Movement': {'Acceleration': 58, 'Sprint spee...  1986-03-27
# 18037   28  {'Movement': {'Acceleration': 79, 'Sprint spee...  1988-08-21
# 18038   30  {'Movement': {'Acceleration': 88, 'Sprint spee...  1987-01-24
# 18039   25  {'Movement': {'Acceleration': 94, 'Sprint spee...  1992-02-05
# 18040   30  {'Movement': {'Acceleration': 92, 'Sprint spee...  1987-06-24
#
#         Body type  Height cm  International reputation           Known as  \
# 0      C. Ronaldo        185                         5  Cristiano Ronaldo
# 1          Normal        191                         4         M. Hummels
# 2            Lean        186                         3           D. Godín
# 3          Normal        195                         5     Z. Ibrahimović
# 4          Normal        165                         3        M. Verratti
# 5          Normal        173                         4        David Silva
# 6          Normal        168                         3           N. Kanté
# 7          Normal        180                         4          A. Robben
# 8          Normal        193                         3      S. Handanovič
# 9            Lean        188                         4          H. Lloris
# 10         Stocky        192                         4         J. Boateng
# 11           Lean        190                         3         L. Bonucci
# 12           Lean        187                         3      P. Aubameyang
# 13         Normal        174                         3             Thiago
# 14           Lean        174                         4       A. Griezmann
# 15         Normal        189                         3           J. Oblak
# 16         Normal        170                         3         Jordi Alba
# 17         Normal        187                         3      M. ter Stegen
# 18         Normal        190                         3            B. Leno
# 19         Normal        190                         3            K. Glik
# 20           Lean        191                         3         D. Subašić
# 21         Normal        177                         3      H. Mkhitaryan
# 22         Normal        185                         3           K. Navas
# 23         Normal        175                         3       A. Lacazette
# 24         Normal        178                         3               Koke
# 25         Normal        163                         3         L. Insigne
# 26         Normal        184                         3           Casemiro
# 27           Lean        191                         3          R. Varane
# 28         Normal        189                         3             Morata
# 29         Normal        196                         4            P. Čech
# ...           ...        ...                       ...                ...
# 18011      Normal        171                         4            Iniesta
# 18012      Normal        194                         4              Piqué
# 18013      Normal        183                         4       Thiago Silva
# 18014      Normal        184                         4         I. Rakitić
# 18015      Normal        183                         3          M. Hamšík
# 18016      Normal        174                         4            Marcelo
# 18017        Lean        180                         4            M. Özil
# 18018        Lean        184                         4          E. Cavani
# 18019      Normal        182                         3         C. Eriksen
# 18020      Normal        180                         4           A. Vidal
# 18021        Lean        191                         4           P. Pogba
# 18022      Normal        177                         3          P. Dybala
# 18023        Lean        192                         4          G. Buffon
# 18024      Normal        187                         4       G. Chiellini
# 18025      Normal        173                         4          S. Agüero
# 18026        Lean        183                         4            G. Bale
# 18027        Lean        174                         4          L. Modrić
# 18028      Normal        169                         4         A. Sánchez
# 18029      Normal        181                         4       K. De Bruyne
# 18030    Courtois        199                         4        T. Courtois
# 18031      Normal        186                         4         G. Higuaín
# 18032      Normal        183                         4       Sergio Ramos
# 18033      Normal        182                         4           T. Kroos
# 18034      Normal        173                         4          E. Hazard
# 18035        Lean        193                         4             De Gea
# 18036      Normal        193                         5           M. Neuer
# 18037      Normal        185                         4     R. Lewandowski
# 18038      Normal        182                         5          L. Suárez
# 18039      Neymar        175                         5             Neymar
# 18040       Messi        170                         5           L. Messi
#
#                                     Name     Nationality  Overall rating  \
# 0           C. Ronaldo dos Santos Aveiro        Portugal              94
# 1                           Mats Hummels         Germany              88
# 2                            Diego Godín         Uruguay              88
# 3                     Zlatan Ibrahimović          Sweden              88
# 4                         Marco Verratti           Italy              87
# 5              David Josué Jiménez Silva           Spain              88
# 6                           N'Golo Kanté          France              87
# 7                           Arjen Robben     Netherlands              88
# 8                       Samir Handanovič        Slovenia              88
# 9                            Hugo Lloris          France              88
# 10                        Jérôme Boateng         Germany              88
# 11                      Leonardo Bonucci           Italy              88
# 12             Pierre-Emerick Aubameyang           Gabon              88
# 13                      Thiago Alcântara           Spain              88
# 14                     Antoine Griezmann          France              88
# 15                             Jan Oblak        Slovenia              88
# 16                      Jordi Alba Ramos           Spain              85
# 17                 Marc-André ter Stegen         Germany              85
# 18                            Bernd Leno         Germany              85
# 19                            Kamil Glik          Poland              85
# 20                       Danijel Subašić         Croatia              85
# 21                    Henrikh Mkhitaryan         Armenia              85
# 22                          Keylor Navas      Costa Rica              85
# 23                   Alexandre Lacazette          France              85
# 24                    Jorge Resurrección           Spain              85
# 25                       Lorenzo Insigne           Italy              85
# 26     Carlos Henrique Venancio Casimiro          Brazil              85
# 27                        Raphaël Varane          France              85
# 28            Álvaro Borja Morata Martín           Spain              85
# 29                             Petr Čech  Czech Republic              86
# ...                                  ...             ...             ...
# 18011               Andrés Iniesta Luján           Spain              87
# 18012              Gerard Piqué Bernabeu           Spain              87
# 18013           Thiago Emiliano da Silva          Brazil              87
# 18014                       Ivan Rakitić         Croatia              87
# 18015                       Marek Hamšík        Slovakia              87
# 18016            Marcelo Vieira da Silva          Brazil              87
# 18017                         Mesut Özil         Germany              87
# 18018                     Edinson Cavani         Uruguay              87
# 18019                  Christian Eriksen         Denmark              87
# 18020                       Arturo Vidal           Chile              87
# 18021                         Paul Pogba          France              87
# 18022                       Paulo Dybala       Argentina              88
# 18023                   Gianluigi Buffon           Italy              89
# 18024                  Giorgio Chiellini           Italy              89
# 18025                      Sergio Agüero       Argentina              89
# 18026                        Gareth Bale           Wales              89
# 18027                        Luka Modrić         Croatia              89
# 18028                     Alexis Sánchez           Chile              89
# 18029                    Kevin De Bruyne         Belgium              89
# 18030                   Thibaut Courtois         Belgium              89
# 18031                    Gonzalo Higuaín       Argentina              90
# 18032                Sergio Ramos García           Spain              90
# 18033                         Toni Kroos         Germany              90
# 18034                        Eden Hazard         Belgium              90
# 18035              David De Gea Quintana           Spain              90
# 18036                       Manuel Neuer         Germany              92
# 18037                 Robert Lewandowski          Poland              91
# 18038                        Luis Suárez         Uruguay              92
# 18039         Neymar da Silva Santos Jr.          Brazil              92
# 18040                       Lionel Messi       Argentina              93
#
#                             ...                        Release clause €  \
# 0                           ...                             195800000.0
# 1                           ...                              79200000.0
# 2                           ...                              82000000.0
# 3                           ...                              50000000.0
# 4                           ...                             121300000.0
# 5                           ...                              96200000.0
# 6                           ...                             101100000.0
# 7                           ...                              59400000.0
# 8                           ...                              57800000.0
# 9                           ...                              72200000.0
# 10                          ...                              79200000.0
# 11                          ...                              74800000.0
# 12                          ...                             103700000.0
# 13                          ...                             121600000.0
# 14                          ...                             159400000.0
# 15                          ...                             121100000.0
# 16                          ...                              62500000.0
# 17                          ...                              75400000.0
# 18                          ...                              60400000.0
# 19                          ...                              57000000.0
# 20                          ...                              41800000.0
# 21                          ...                              72200000.0
# 22                          ...                              50200000.0
# 23                          ...                              95800000.0
# 24                          ...                             100900000.0
# 25                          ...                              79900000.0
# 26                          ...                              89300000.0
# 27                          ...                             104600000.0
# 28                          ...                              98200000.0
# 29                          ...                              20000000.0
# ...                         ...                                     ...
# 18011                       ...                              60500000.0
# 18012                       ...                              76900000.0
# 18013                       ...                              53700000.0
# 18014                       ...                              99400000.0
# 18015                       ...                              82500000.0
# 18016                       ...                              77900000.0
# 18017                       ...                              96900000.0
# 18018                       ...                              89700000.0
# 18019                       ...                             128400000.0
# 18020                       ...                              61900000.0
# 18021                       ...                             128000000.0
# 18022                       ...                             136300000.0
# 18023                       ...                               7400000.0
# 18024                       ...                              62700000.0
# 18025                       ...                             123000000.0
# 18026                       ...                             142500000.0
# 18027                       ...                             116900000.0
# 18028                       ...                             128300000.0
# 18029                       ...                             159800000.0
# 18030                       ...                             113600000.0
# 18031                       ...                             127100000.0
# 18032                       ...                             106600000.0
# 18033                       ...                             162000000.0
# 18034                       ...                             174200000.0
# 18035                       ...                             124200000.0
# 18036                       ...                             100700000.0
# 18037                       ...                             151800000.0
# 18038                       ...                             198900000.0
# 18039                       ...                             236800000.0
# 18040                       ...                             215300000.0
#
#       Skill moves                             Specialities  \
# 0               5                                      NaN
# 1               2                                      NaN
# 2               2                                      NaN
# 3               4                                      NaN
# 4               3                                      NaN
# 5               4                                      NaN
# 6               3  {'Tackling ': True, 'Tactician ': True}
# 7               4                                      NaN
# 8               1                                      NaN
# 9               1                                      NaN
# 10              2                                      NaN
# 11              2                                      NaN
# 12              3                                      NaN
# 13              5                                      NaN
# 14              4                                      NaN
# 15              1                                      NaN
# 16              3     {'Acrobat': True, 'Speedster': True}
# 17              1                                      NaN
# 18              1                                      NaN
# 19              2                                      NaN
# 20              1                                      NaN
# 21              4                                      NaN
# 22              1                                      NaN
# 23              4                                      NaN
# 24              3                                      NaN
# 25              4                                      NaN
# 26              2                                      NaN
# 27              2                      {'Tackling ': True}
# 28              3                                      NaN
# 29              1                                      NaN
# ...           ...                                      ...
# 18011           4                                      NaN
# 18012           2                                      NaN
# 18013           3                                      NaN
# 18014           3                                      NaN
# 18015           3                                      NaN
# 18016           4                                      NaN
# 18017           4                                      NaN
# 18018           3                                      NaN
# 18019           4                                      NaN
# 18020           3                                      NaN
# 18021           5                                      NaN
# 18022           4                                      NaN
# 18023           1                                      NaN
# 18024           2                                      NaN
# 18025           4                                      NaN
# 18026           4                                      NaN
# 18027           4                                      NaN
# 18028           4                                      NaN
# 18029           4                                      NaN
# 18030           1                                      NaN
# 18031           3                                      NaN
# 18032           3                                      NaN
# 18033           3                                      NaN
# 18034           4                                      NaN
# 18035           1                                      NaN
# 18036           1                                      NaN
# 18037           3                                      NaN
# 18038           4                                      NaN
# 18039           5                                      NaN
# 18040           4                                      NaN
#
#                                                    Teams  \
# 0      {'Club': {'Position': 'LS', 'Jersey number': '...
# 1      {'Club': {'Position': 'LCB', 'Jersey number': ...
# 2      {'Club': {'Position': 'LCB', 'Jersey number': ...
# 3      {'Club': {'Position': 'SUB', 'Jersey number': ...
# 4      {'Club': {'Position': 'RCM', 'Jersey number': ...
# 5      {'Club': {'Position': 'LCM', 'Jersey number': ...
# 6      {'Club': {'Position': 'RCM', 'Jersey number': ...
# 7      {'Club': {'Position': 'RM', 'Jersey number': '...
# 8      {'Club': {'Position': 'GK', 'Jersey number': '...
# 9      {'Club': {'Position': 'GK', 'Jersey number': '...
# 10     {'Club': {'Position': 'RCB', 'Jersey number': ...
# 11     {'Club': {'Position': 'CB', 'Jersey number': '...
# 12     {'Club': {'Position': 'ST', 'Jersey number': '...
# 13     {'Club': {'Position': 'LDM', 'Jersey number': ...
# 14     {'Club': {'Position': 'LS', 'Jersey number': '...
# 15     {'Club': {'Position': 'GK', 'Jersey number': '...
# 16     {'Club': {'Position': 'LB', 'Jersey number': '...
# 17     {'Club': {'Position': 'GK', 'Jersey number': '...
# 18     {'Club': {'Position': 'GK', 'Jersey number': '...
# 19     {'Club': {'Position': 'RCB', 'Jersey number': ...
# 20     {'Club': {'Position': 'GK', 'Jersey number': '...
# 21     {'Club': {'Position': 'CAM', 'Jersey number': ...
# 22     {'Club': {'Position': 'GK', 'Jersey number': '...
# 23     {'Club': {'Position': 'ST', 'Jersey number': '...
# 24     {'Club': {'Position': 'RM', 'Jersey number': '...
# 25     {'Club': {'Position': 'LW', 'Jersey number': '...
# 26     {'Club': {'Position': 'CDM', 'Jersey number': ...
# 27     {'Club': {'Position': 'RCB', 'Jersey number': ...
# 28     {'Club': {'Position': 'ST', 'Jersey number': '...
# 29     {'Club': {'Position': 'GK', 'Jersey number': '...
# ...                                                  ...
# 18011  {'Club': {'Position': 'LM', 'Jersey number': '...
# 18012  {'Club': {'Position': 'RCB', 'Jersey number': ...
# 18013  {'Club': {'Position': 'LCB', 'Jersey number': ...
# 18014  {'Club': {'Position': 'RCM', 'Jersey number': ...
# 18015  {'Club': {'Position': 'LCM', 'Jersey number': ...
# 18016  {'Club': {'Position': 'LB', 'Jersey number': '...
# 18017  {'Club': {'Position': 'RW', 'Jersey number': '...
# 18018  {'Club': {'Position': 'ST', 'Jersey number': '...
# 18019  {'Club': {'Position': 'LCM', 'Jersey number': ...
# 18020  {'Club': {'Position': 'SUB', 'Jersey number': ...
# 18021  {'Club': {'Position': 'SUB', 'Jersey number': ...
# 18022  {'Club': {'Position': 'CAM', 'Jersey number': ...
# 18023  {'Club': {'Position': 'GK', 'Jersey number': '...
# 18024  {'Club': {'Position': 'LCB', 'Jersey number': ...
# 18025  {'Club': {'Position': 'ST', 'Jersey number': '...
# 18026  {'Club': {'Position': 'SUB', 'Jersey number': ...
# 18027  {'Club': {'Position': 'RCM', 'Jersey number': ...
# 18028  {'Club': {'Position': 'LW', 'Jersey number': '...
# 18029  {'Club': {'Position': 'RCM', 'Jersey number': ...
# 18030  {'Club': {'Position': 'GK', 'Jersey number': '...
# 18031  {'Club': {'Position': 'ST', 'Jersey number': '...
# 18032  {'Club': {'Position': 'LCB', 'Jersey number': ...
# 18033  {'Club': {'Position': 'LCM', 'Jersey number': ...
# 18034  {'Club': {'Position': 'LW', 'Jersey number': '...
# 18035  {'Club': {'Position': 'GK', 'Jersey number': '...
# 18036  {'Club': {'Position': 'RES', 'Jersey number': ...
# 18037  {'Club': {'Position': 'ST', 'Jersey number': '...
# 18038  {'Club': {'Position': 'LS', 'Jersey number': '...
# 18039  {'Club': {'Position': 'LW', 'Jersey number': '...
# 18040  {'Club': {'Position': 'RS', 'Jersey number': '...
#
#                                                   Traits    Value €  Wage €  \
# 0      {'Flair': True, 'Speedster': True, 'Skilled dr...   95500000  565000
# 1      {'Playmaker': True, 'Long passer': True, 'Tack...   48000000  215000
# 2      {'Power header': True, 'Aerial threat': True, ...   40000000  125000
# 3      {'Flair': True, 'Technical dribbler': True, 'B...   27000000  240000
# 4      {'Playmaker': True, 'Acrobat': True, 'Tacticia...   63000000  130000
# 5      {'Flair': True, 'Playmaker': True, 'Avoids usi...   52000000  285000
# 6                                                    NaN   52500000  190000
# 7      {'Chip shot': True, 'Avoids using weaker foot'...   36000000  225000
# 8      {'1-on-1 rush': True, 'Puncher': True, 'GK lon...   34000000  120000
# 9      {'Comes for crosses': True, 'Avoids using weak...   38000000  165000
# 10     {'Long passer': True, 'Tackling ': True, 'Long...   48000000  215000
# 11     {'Long passer': True, 'Leadership': True, 'Tac...   44000000  210000
# 12     {'Chip shot': True, 'Speedster': True, 'Poache...   61000000  165000
# 13     {'Flair': True, 'Takes finesse free kicks': Tr...   70500000  225000
# 14     {'Tries to beat defensive line': True, 'Dribbl...   75000000  150000
# 15     {'Comes for crosses': True, 'Puncher': True, '...   57000000   82000
# 16                                                   NaN   30500000  215000
# 17     {'Comes for crosses': True, 'Rushes Out Of Goa...   35500000  155000
# 18                       {'Cautious with crosses': True}   34000000   61000
# 19     {'Dives into tackles': True, 'Long passer': Tr...   30000000   60000
# 20                       {'Cautious with crosses': True}   22000000   46000
# 21     {'Flair': True, 'Playmaker': True, 'Engine': T...   39000000  195000
# 22     {'GK up for corners': True, 'GK long throw': T...   24500000  165000
# 23                      {'Flair': True, 'Acrobat': True}   48500000  180000
# 24     {'Playmaker': True, 'Long passer': True, 'Play...   47500000   84000
# 25     {'Speedster': True, 'Finesse shot': True, 'Tak...   45000000  115000
# 26     {'Power free kick': True, 'Long passer': True,...   42000000  195000
# 27                                                   NaN   46500000  175000
# 28     {'Tries to beat defensive line': True, 'Skille...   51000000  170000
# 29     {'Team player': True, 'Puncher': True, 'GK lon...   10500000   92000
# ...                                                  ...        ...     ...
# 18011  {'Playmaker': True, 'Team player': True, 'Drib...   29500000  260000
# 18012  {'Long passer': True, 'Tackling ': True, 'Aeri...   37500000  240000
# 18013  {'Power header': True, 'Leadership': True, 'Ta...   29000000  135000
# 18014  {'Finesse shot': True, 'Corner specialist': Tr...   48500000  275000
# 18015  {'Long shot taker': True, 'Team player': True,...   48500000  130000
# 18016  {'Flair': True, 'Crosser': True, 'Dribbler': T...   38000000  250000
# 18017  {'Flair': True, 'Playmaker': True, 'Finesse sh...   51000000  205000
# 18018  {'Power header': True, 'Tries to beat defensiv...   48500000  160000
# 18019  {'Flair': True, 'Playmaker': True, 'Long shot ...   65000000  165000
# 18020  {'Engine': True, 'Long shot taker': True, 'Div...   37500000  160000
# 18021  {'Flair': True, 'Long passer': True, 'Playmake...   66500000  195000
# 18022  {'Flair': True, 'Playmaker': True, 'Avoids usi...   79000000  215000
# 18023  {'Leadership': True, 'Team player': True, 'Cau...    4500000  110000
# 18024  {'Long throw-in': True, 'Dives into tackles': ...   38000000  225000
# 18025  {'Flair': True, 'Tries to beat defensive line'...   66500000  325000
# 18026  {'Chip shot': True, 'Crosser': True, 'Speedste...   69500000  370000
# 18027  {'Playmaker': True, 'Long passer': True, 'Drib...   57000000  340000
# 18028  {'Flair': True, 'Acrobat': True, 'Long shot ta...   67500000  265000
# 18029  {'Playmaker': True, 'Long passer': True, 'Engi...   83000000  285000
# 18030  {'Comes for crosses': True, 'GK long throw': T...   59000000  190000
# 18031  {'Outside foot shot': True, 'Clinical finisher...   77000000  275000
# 18032  {'Leadership': True, 'Dives into tackles': Tru...   52000000  310000
# 18033  {'Playmaker': True, 'Long passer': True, 'Tech...   79000000  340000
# 18034  {'Flair': True, 'Playmaker': True, 'Speedster'...   90500000  295000
# 18035   {'Saves with Feet': True, 'GK long throw': True}   64500000  215000
# 18036  {'Comes for crosses': True, '1-on-1 rush': Tru...   61000000  230000
# 18037  {'Chip shot': True, 'Injury free': True, 'Fine...   92000000  355000
# 18038  {'Diver': True, 'Tries to beat defensive line'...   97000000  510000
# 18039  {'Flair': True, 'Speedster': True, 'Diver': Tr...  123000000  280000
# 18040  {'Playmaker': True, 'Chip shot': True, 'Long s...  105000000  565000
#
#       Weak foot Weight kg                                       Work rate
# 0             4        80       {'Defensive': 'Low', 'Attacking': 'High'}
# 1             3        92    {'Defensive': 'Medium', 'Attacking': 'High'}
# 2             3        78    {'Defensive': 'High', 'Attacking': 'Medium'}
# 3             4        95     {'Defensive': 'Low', 'Attacking': 'Medium'}
# 4             4        60    {'Defensive': 'High', 'Attacking': 'Medium'}
# 5             2        67       {'Defensive': 'Low', 'Attacking': 'High'}
# 6             3        68    {'Defensive': 'High', 'Attacking': 'Medium'}
# 7             2        80       {'Defensive': 'Low', 'Attacking': 'High'}
# 8             2        92  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 9             1        82  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 10            4        90  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 11            3        85       {'Defensive': 'High', 'Attacking': 'Low'}
# 12            4        80     {'Defensive': 'Low', 'Attacking': 'Medium'}
# 13            3        70  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 14            3        72    {'Defensive': 'Medium', 'Attacking': 'High'}
# 15            3        82  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 16            3        68    {'Defensive': 'Medium', 'Attacking': 'High'}
# 17            4        85  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18            4        83  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 19            2        80     {'Defensive': 'Medium', 'Attacking': 'Low'}
# 20            2        84  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 21            5        75      {'Defensive': 'High', 'Attacking': 'High'}
# 22            3        78  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 23            3        73    {'Defensive': 'Medium', 'Attacking': 'High'}
# 24            4        74      {'Defensive': 'High', 'Attacking': 'High'}
# 25            3        59    {'Defensive': 'Medium', 'Attacking': 'High'}
# 26            3        80    {'Defensive': 'High', 'Attacking': 'Medium'}
# 27            3        78    {'Defensive': 'High', 'Attacking': 'Medium'}
# 28            4        85      {'Defensive': 'High', 'Attacking': 'High'}
# 29            3        90  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# ...         ...       ...                                             ...
# 18011         4        68    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18012         3        85    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18013         3        79      {'Defensive': 'High', 'Attacking': 'High'}
# 18014         3        78  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18015         5        79    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18016         4        75    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18017         2        76     {'Defensive': 'Low', 'Attacking': 'Medium'}
# 18018         3        71      {'Defensive': 'High', 'Attacking': 'High'}
# 18019         5        76    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18020         4        75      {'Defensive': 'High', 'Attacking': 'High'}
# 18021         4        84    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18022         3        75    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18023         2        92  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18024         2        85       {'Defensive': 'High', 'Attacking': 'Low'}
# 18025         4        70    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18026         3        74    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18027         4        65    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18028         3        62      {'Defensive': 'High', 'Attacking': 'High'}
# 18029         4        68      {'Defensive': 'High', 'Attacking': 'High'}
# 18030         3        94  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18031         4        89    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18032         3        75    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18033         5        78  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18034         4        76    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18035         3        76  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18036         4        92  {'Defensive': 'Medium', 'Attacking': 'Medium'}
# 18037         4        79    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18038         4        86    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18039         5        68    {'Defensive': 'Medium', 'Attacking': 'High'}
# 18040         4        72  {'Defensive': 'Medium', 'Attacking': 'Medium'}
#
# [18041 rows x 24 columns]
