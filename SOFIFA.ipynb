# %%
import datetime
import requests
from scrapy.http import TextResponse

# %%
import re

def text_cleaner(text):
    return [item.strip() for item in text if not re.match('^(\r\n|\s)+$', item)]

# %%
def money(value):
    
    quantity, multiplier = re.search('([\d\.]+)(M|K)?', value).groups()
    quantity = float(quantity)
    
    if multiplier:
        multiplier = {'M':1000000, 'K':1000}[multiplier]
    else:
        multiplier = 1
    
    return int(quantity * multiplier)

# %% [markdown]
# ## Teams

# %%
#r = requests.get('https://sofifa.com/team/1415')
#response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
#team = {}
#team_basic(response, team)
#team_stats(response, team)
#team_lineup(response, team)
#team_info(response, team)
#team

# %%
def team_basic(response, team):
    raw   = response.css('div.info').xpath('.//text()').extract()
    clean = text_cleaner(raw)

    team['Name'], team['Team ID'] = re.match('([\w\s\.\-\']+) \(ID: (\d+)\)', clean[0]).groups()
    team['League'] = clean[1]
    team['Nationality'] = response.css('div.info').xpath('.//a[contains(@href, "teams?na=")]/@title').extract_first()

# %%
def team_lineup(response, team):
    team['Lineup'] = []

    for position in response.xpath('.//div[@class="field-player"]'):
        pos = {}
 
        y, x = position.xpath('./@style').re('top:([\d\.\-]+)px;left:([\d\.\-]+)px;')
        
        pos['Player ID']   = position.xpath('./a/@href').re_first('\d+')
        pos['y'], pos['x'] = float(y), float(x)
        
        rows = position.xpath('.//span[@class="nowrap row"]')

        if len(rows) == 0:
            pos['Position'] = 'GK'
        else:
            pos['Instructions'] = {}

            for row in rows:
                instruction, value = text_cleaner(row.xpath('.//text()').extract())

                if re.search('instructions', value, re.IGNORECASE):
                    pos['Position'] = instruction
                else:
                    pos['Instructions'][instruction] = value.lower()

        team['Lineup'].append(pos)

# %%
def team_stats(response, team):
    extract = lambda stat: response.xpath('//span[contains(.., $concept)]/text()', concept=stat).extract_first()

    stats = ['Overall', 'Attack', 'Midfield', 'Defence']

    for stat in stats:
        team[stat] = int(extract(stat))

# %%
def team_info(response, team):
     
    raw = response.xpath('//li[contains(label, "Home stadium")]/text()').extract()
    team['Home stadium'] = text_cleaner(raw)[0]
    
    raw = response.xpath('//li[contains(label, "Transfer budget")]/text()').extract()
    
    if raw:
        team['Transfer budget €'] = money(text_cleaner(raw)[0])

    for concept in ['Starting 11 average age', 'Whole team average age']:
        raw = response.xpath('//li[contains(label, $concept)]/text()', concept=concept).extract()
        team[concept] = float(text_cleaner(raw)[0])
        
    for concept in ['International prestige', 'Domestic prestige']:
        raw = response.xpath('//li[contains(label, $concept)]/span/text()', concept=concept).extract_first()
        if raw:
            team[concept] = int(raw)
        
    for concept in ['Rival team', 'Captain', 'Short free kick', 'Long free kick', 'Penalties', 'Left corner', 'Right corner']:
        team[concept + ' ID'] = response.xpath('//li[contains(label, $concept)]/a/@href', concept=concept).re_first('\d+')

# %% [markdown]
# ## Players

# %%
#r = requests.get('https://sofifa.com/player/232171')
#response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
#player = {}
#basic(response, player)
#stats(response, player)
#body(response, player)
#composed_attributes(response, player)
#teams(response, player)
#attributes(response, player)
#traits_and_specialities(response, player)
#player

# %% [markdown]
# ### Header — Basic info

# %%
def basic(response, player):
    
    # 'Known as'
    # 'Player ID'
    # 'Name'
    # 'Nationality' 
    # 'Positions'
    # 'Birth date'
    # 'Height [cm]'
    # 'Weight [kg]'

    raw   = response.css('div.info').xpath('.//text()').extract()
    clean = text_cleaner(raw)

    player['Known as'], player['Player ID'] = re.match('([\w\s.]+) \(ID: (\d+)\)', clean[0]).groups()
    player['Name'] = clean[1]
    player['Positions'] = {}
    
    for position in clean[2:-1]:
        player['Positions'][position] = True

    match = re.match('Age (\d+) \((\w{3} \d{1,2}, \d{4})\) (\d{3})cm (\d{2,3})kg', clean[-1]) 
    
    player['Age']        = int(match.group(1))
    player['Birth date'] = datetime.datetime.strptime(match.group(2), '%b %d, %Y').strftime('%Y-%m-%d')
    player['Height cm']  = int(match.group(3))
    player['Weight kg']  = int(match.group(4))
    
    player['Nationality'] = response.css('div.info').xpath('.//a[contains(@href, "players?na=")]/@title').extract_first()

# %% [markdown]
# ### Subheader — Stats

# %%
def stats(response, player):
    
    # 'Overall rating'
    # 'Potential'
    # 'Value'
    # 'Wage'
    
    extract = lambda stat: response.xpath('//span[contains(.., $concept)]/text()', concept=stat).extract_first()
       
    player['Overall rating'] = int(  extract('Overall rating'))
    player['Potential']      = int(  extract('Potential'))
    player['Value €']        = money(extract('Value'))
    player['Wage €']         = money(extract('Wage'))

# %% [markdown]
# ### First column — Body

# %%
def body(response, player):
    
    extract = lambda concept: response.xpath('//li[contains(., $concept)]', concept=concept).xpath('(./span|.)/text()').extract()
        
    for concept in ['International reputation', 'Weak foot', 'Skill moves']:
        raw = extract(concept)
        
        if len(raw) == 0: continue
            
        player[concept] = int(text_cleaner(raw)[0])
    
    
    for concept in ['Body type', 'Preferred foot']:
        raw = extract(concept)
        
        if len(raw) == 0: continue
            
        player[concept] = text_cleaner(raw)[0]
        
        
    raw = extract('Work rate')
    
    if len(raw) > 0:
        work_rate = {}
        work_rate['Attacking'], work_rate['Defensive'] = text_cleaner(raw)[0].split(' / ')
        player['Work rate'] = work_rate
    
    
    raw = extract('Release clause')
    
    if len(raw) > 0:
        player['Release clause €'] = money(text_cleaner(raw)[0])

# %% [markdown]
# ### Second column — Composed attributes

# %%
def composed_attributes(response, player):
    raw = response.xpath('//script[contains(text(), "PHY")]/text()').extract_first()
    
    if not raw: return
    
    player['Composed attributes'] = {}
    
    for attribute, value in re.findall('point(\w{3}) = (\d{1,3})', raw):
        player['Composed attributes'][attribute] = int(value)

# %% [markdown]
# ### Third and fourth columns — Teams

# %%
def teams(response, player):
    
    concepts = [
        'Position',
        'Jersey number',
        'Joined',
        'Loaned from',
        'Contract valid until',
    ]
    
    player['Teams'] = {}
    
    for team_column in response.xpath('//a[contains(@href, "team/")]/ancestor::ul'):

        data = {}
        data['Team ID'] = team_column.xpath('.//@href[contains(., "team/")]').re_first('\d+')

        for concept in concepts:
            raw = team_column.xpath('.//li[contains(label, $concept)]', concept=concept) \
                  .xpath('./span | .').xpath('./text() | a/@href').extract()

            if len(raw) == 0: continue

            clean = text_cleaner(raw)[0]

            if   concept == 'Joined':
                data[concept] = datetime.datetime.strptime(clean, '%b %d, %Y').strftime('%Y-%m-%d')
            elif concept == 'Loaned from':
                data[concept] = re.search('\d+', clean).group(0)
            elif concept == 'Contract valid until':
                # this is because in a few cases the date is like "Dec 31, 2017" instead of "2017"
                data[concept] = clean[-4:]
            else:
                data[concept] = clean
            
        if 'Contract valid until' in data: # team type is "club"
            player['Teams']['Club'] = data
        else: # team type is "national"
            player['Teams']['National'] = data

# %% [markdown]
# ### 5th to 7th columns — Attributes

# %%
def attributes(response, player):

    attributes = {
      'Attacking': [
        'Crossing',
        'Finishing',
        'Heading accuracy',
        'Short passing',
        'Volleys',
      ],
      'Skill': [
         'Dribbling',
         'Curve',
         'Free kick accuracy',
         'Long passing',
         'Ball control',
      ],
      'Movement': [
        'Acceleration',
        'Sprint speed',
        'Agility',
        'Reactions',
        'Balance',
      ],
      'Power': [
        'Shot power',
        'Jumping',
        'Stamina',
        'Strength',
        'Long shots',    
      ],
      'Mentality': [
        'Aggression',
        'Interceptions',
        'Positioning',
        'Vision',
        'Penalties',
        'Composure',
      ],
      'Defending': [
        'Marking',
        'Standing tackle',
        'Sliding tackle',
      ],
      'Goalkeeping': [
        'GK diving',
        'GK handling',
        'GK kicking',
        'GK positioning',
        'GK reflexes',
      ],
    }
    
    player['Attributes'] = {}

    for group in attributes:
        player['Attributes'][group] = {}
        
        for attribute in attributes[group]:
            player['Attributes'][group][attribute] = \
                int(response.xpath('//span[contains(.., $concept)]/text()', concept=attribute).extract_first())

# %% [markdown]
# ### 8th column — Traits and specialities

# %%
def traits_and_specialities(response, player):

    for group in ['Traits', 'Specialities']:
        skills = response.xpath('//div[contains(h5, $concept)]/ul/li/text()', concept=group).extract()
        
        if len(skills) == 0: continue
        
        player[group] = {}
        
        for skill in skills:
            player[group][skill] = True

# %% [markdown]
# ## Crawler

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from scrapy.crawler import CrawlerProcess

import logging
import datetime
import scrapy

# %%
class PlayerSpider(scrapy.Spider):
    name = 'Player'
    
    start_urls = [
        'https://sofifa.com/players?units=mks&currency=EUR',
    ]
    
    custom_settings = {
        'LOG_LEVEL':   logging.WARNING,
        'FEED_FORMAT': 'json',
        'FEED_URI':    'players.json'
    }
    
    def parse(self, response):
        # follow links to player pages
        for href in response.xpath('//a[contains(@href, "player/")]/@href'):
            yield response.follow(href, self.parse_player)

        # follow pagination links
        #for href in response.xpath('//a[contains(@href, "players?offset=") and contains(text(), "Next")]/@href'):
        #    yield response.follow(href, self.parse)      

            
    def parse_player(self, response):
        player = {}

        basic(response, player)
        stats(response, player)
        body(response, player)
        teams(response, player)
        attributes(response, player)
        traits_and_specialities(response, player)

        yield player

# %%
class TeamSpider(scrapy.Spider):
    name = 'Team'
    
    start_urls = [
        'https://sofifa.com/teams/national?units=mks&currency=EUR',
        'https://sofifa.com/teams/club?units=mks&currency=EUR'
    ]
    
    custom_settings = {
        'LOG_LEVEL':   logging.WARNING,
        'FEED_FORMAT': 'json',
        'FEED_URI':    'teams.json'
    }
    
    def parse(self, response):
        # follow links to player pages
        for href in response.xpath('//a[contains(@href, "team/")]/@href'):
            yield response.follow(href, self.parse_team)

        # follow pagination links
        #for href in response.xpath('//a[contains(@href, "players?offset=") and contains(text(), "Next")]/@href'):
        #    yield response.follow(href, self.parse)      

            
    def parse_team(self, response):
        team = {}

        team_basic(response, team)
        team_stats(response, team)
        team_lineup(response, team)
        team_info(response, team)

        yield team

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(TeamSpider)
process.start()
# Out:
# 2017-11-12 18:20:40 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-11-12 18:20:40 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}

# %%
import pandas as pd
dfjson = pd.read_json('teams.json')
dfjson
# Out:
#      Attack  Captain ID  Defence  Domestic prestige  \
# 0        84      155862       86                NaN
# 1        79      188033       70                NaN
# 2        87      155862       86               10.0
# 3        79      191053       68                NaN
# 4        71      167905       72                NaN
# 5        73      168580       69                NaN
# 6        73      191256       73                NaN
# 7        68      151508       74                NaN
# 8        72       51412       71                NaN
# 9        72      189167       69                NaN
# 10       72      219911       70                NaN
# 11       74      187043       72                NaN
# 12       79      205943       71                NaN
# 13       72      182879       71                NaN
# 14       76      135883       75                3.0
# 15       76      173474       74                4.0
# 16       76      143076       76                5.0
# 17       76      186953       75                6.0
# 18       78      193686       73                6.0
# 19       77      137351       75                2.0
# 20       71      139274       74                NaN
# 21       75      191688       73               10.0
# 22       78      164079       73               10.0
# 23       75      172287       74                1.0
# 24       74      216373       76                8.0
# 25       76      199767       74               10.0
# 26       74      203487       75               10.0
# 27       76      201988       75                5.0
# 28       78      201893       76                5.0
# 29       75      138782       73                NaN
# ..      ...         ...      ...                ...
# 100      76      185090       68                NaN
# 101      71      172862       69                NaN
# 102      75      155887       74                NaN
# 103      88        9014       85               10.0
# 104      76      140222       73                NaN
# 105      82      163824       76                NaN
# 106      76      187489       75                NaN
# 107      77      156713       76                NaN
# 108      75      188768       77                NaN
# 109      75      181262       75                NaN
# 110      78      189606       77                NaN
# 111      75      179645       75                NaN
# 112      81      181459       79                NaN
# 113      79      174543       77                NaN
# 114      77      148119       75                NaN
# 115      82      188545       77                NaN
# 116      76      108080       76                NaN
# 117      80      198710       78                NaN
# 118      85      182493       79                NaN
# 119      82      202126       81                NaN
# 120      77      143745       79                NaN
# 121      79      189712       80                NaN
# 122      84      158023       81                NaN
# 123      81        1179       83                NaN
# 124      86       20801       80                NaN
# 125      84      167948       82                NaN
# 126      83      183277       85                NaN
# 127      82      167495       83                NaN
# 128      78      171897       75                NaN
# 129      85      187961       85                NaN
#
#                              Home stadium  International prestige  \
# 0                       Santiago Bernabéu                       9
# 1           El Monumento (Estadio Latino)                       5
# 2                       Santiago Bernabéu                      10
# 3                              Euro Arena                       2
# 4                              Euro Arena                       5
# 5                                 O Dromo                       3
# 6                       King Fahd Stadium                       4
# 7           Molton Road (Sheldon Stadium)                       2
# 8                          Stadion Hanguk                       5
# 9                              Euro Arena                       2
# 10             Estadio Presidente G.Lopes                       4
# 11      Eastpoint Arena (Football Ground)                       4
# 12          Waldstadion (Fussballstadion)                       5
# 13                          Stadion Neder                       4
# 14   Vitality Stadium (Goldsands Stadium)                       3
# 15          Waldstadion (Fussballstadion)                       4
# 16                        Stadio Classico                       4
# 17                             Euro Arena                       5
# 18      Stadion Europa (Generic Europe 2)                       4
# 19                          Stadion Neder                       4
# 20          Molton Road (Sheldon Stadium)                       5
# 21                          Stadion Neder                       6
# 22          El Libertador (La Bombastico)                       7
# 23                        Stade Municipal                       1
# 24                        Stadio Classico                       6
# 25          Waldstadion (Fussballstadion)                       6
# 26   Sports Direct Arena (St James' Park)                       3
# 27                        Liberty Stadium                       4
# 28          El Libertador (La Bombastico)                       2
# 29                        Stadion Olympik                       4
# ..                                    ...                     ...
# 100        Aloha Park (Generic Oceania 2)                       5
# 101                       Stadion Olympik                       3
# 102                     CenturyLink Field                       6
# 103                         Allianz Arena                      10
# 104                       Stadio Classico                       4
# 105                              Ivy Lane                       4
# 106  Sanderson Park (FIFA 13 NEW generic)                       5
# 107   Forest Park Stadium (Square Ground)                       5
# 108        Aloha Park (Generic Oceania 2)                       6
# 109                         Stadion Neder                       5
# 110                       Stadion Olympik                       4
# 111         Waldstadion (Fussballstadion)                       5
# 112                         Stadion Neder                       6
# 113         El Monumento (Estadio Latino)                       7
# 114         Waldstadion (Fussballstadion)                       6
# 115  Sanderson Park (FIFA 13 NEW generic)                       5
# 116         Waldstadion (Fussballstadion)                       5
# 117                               O Dromo                       7
# 118         El Libertador (La Bombastico)                       7
# 119                       Wembley Stadium                       8
# 120                            Euro Arena                       6
# 121                       Amsterdam ArenA                       8
# 122                         El Monumental                       9
# 123                       Stadio Olimpico                       9
# 124         Waldstadion (Fussballstadion)                       8
# 125                       Stadion Olympik                       9
# 126                       Stadion Olympik                       7
# 127                        Olympiastadion                      10
# 128                        Estadio Azteca                       7
# 129                               O Dromo                      10
#
#                            League  Left corner ID  \
# 0                   International          193747
# 1                   International          209331
# 2    Spanish Primera División (1)          182521
# 3                   International          191053
# 4                   International          167905
# 5                   International          210951
# 6                   International          209281
# 7                   International          186143
# 8                   International          194958
# 9                   International          184484
# 10                  International          225139
# 11                  International          187043
# 12                  International          211061
# 13                  International          137089
# 14     English Premier League (1)          169638
# 15          German Bundesliga (1)          173474
# 16            Italian Serie A (1)          143076
# 17          Turkish Süper Lig (1)          189491
# 18            Italian Serie A (1)          201508
# 19          German Bundesliga (1)          137351
# 20                  International          200647
# 21         Greek Super League (1)          203980
# 22            Mexican Liga MX (1)          192350
# 23   Spanish Primera División (1)          199416
# 24   Portuguese Primeira Liga (1)          213516
# 25         Holland Eredivisie (1)          221992
# 26     English Premier League (1)          186395
# 27     English Premier League (1)          202491
# 28   Spanish Primera División (1)          222943
# 29                  International          188166
# ..                            ...             ...
# 100                 International          185090
# 101                 International          172233
# 102                 International          227796
# 103         German Bundesliga (1)          197445
# 104                 International          220334
# 105                 International          186561
# 106                 International          201884
# 107                 International          208448
# 108                 International          215798
# 109                 International          226592
# 110                 International          197445
# 111                 International          190460
# 112                 International          203980
# 113                 International          184941
# 114                 International          147621
# 115                 International          177922
# 116                 International          193348
# 117                 International          198710
# 118                 International          170664
# 119                 International          231677
# 120                 International          124607
# 121                 International          208808
# 122                 International          158023
# 123                 International          198219
# 124                 International          218667
# 125                 International          194765
# 126                 International          192985
# 127                 International          182521
# 128                 International          226045
# 129                 International          190871
#
#                                                 Lineup  Long free kick ID  \
# 0    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             193747
# 1    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             226078
# 2    [{'x': 132.6, 'Position': 'LS', 'Player ID': '...              20801
# 3    [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             191053
# 4    [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             204738
# 5    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             210951
# 6    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             168883
# 7    [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             186143
# 8    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             194958
# 9    [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             184484
# 10   [{'x': 4.5, 'Position': 'LW', 'Player ID': '22...             203594
# 11   [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             187043
# 12   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             211061
# 13   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             137089
# 14   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             184469
# 15   [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             173474
# 16   [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             143076
# 17   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             175671
# 18   [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             201508
# 19   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             137351
# 20   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             200647
# 21   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             175895
# 22   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             186992
# 23   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             199416
# 24   [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             188086
# 25   [{'x': 15.0, 'Position': 'LW', 'Player ID': '2...             212755
# 26   [{'x': 178.8, 'Position': 'ST', 'Player ID': '...             186395
# 27   [{'x': 132.6, 'Position': 'LS', 'Player ID': '...             202491
# 28   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             216468
# 29   [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             202539
# ..                                                 ...                ...
# 100  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             175896
# 101  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             172233
# 102  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             155887
# 103  [{'x': 184.05, 'Position': 'ST', 'Player ID': ...             197445
# 104  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             220334
# 105  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             186561
# 106  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             201884
# 107  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             208448
# 108  [{'x': 4.5, 'Position': 'LW', 'Player ID': '22...             188768
# 109  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             226592
# 110  [{'x': 4.5, 'Position': 'LW', 'Player ID': '18...             197445
# 111  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             190460
# 112  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             202151
# 113  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             181872
# 114  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             187366
# 115  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             210406
# 116  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             193348
# 117  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             198710
# 118  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             170664
# 119  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             202335
# 120  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             124607
# 121  [{'x': 15.0, 'Position': 'LW', 'Player ID': '1...             203376
# 122  [{'x': 4.5, 'Position': 'LW', 'Player ID': '18...             158023
# 123  [{'x': 15.0, 'Position': 'LW', 'Player ID': '1...             173221
# 124  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...              20801
# 125  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             195864
# 126  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             192985
# 127  [{'x': 182.79, 'Position': 'ST', 'Player ID': ...             182521
# 128  [{'x': 136.8, 'Position': 'LS', 'Player ID': '...             171897
# 129  [{'x': 15.0, 'Position': 'LW', 'Player ID': '1...             146530
#
#               ...                    Nationality Overall Penalties ID  \
# 0             ...                          Spain      86       168542
# 1             ...                          Egypt      72       209331
# 2             ...                          Spain      86        20801
# 3             ...                      Venezuela      72       189250
# 4             ...                        Ecuador      72       167905
# 5             ...                           Peru      71       204538
# 6             ...                   Saudi Arabia      73       208916
# 7             ...               Northern Ireland      71       151508
# 8             ...                      Australia      73       176992
# 9             ...                        Iceland      72       184484
# 10            ...                   South Africa      72       193234
# 11            ...                         Norway      74       185422
# 12            ...                        Romania      72       200911
# 13            ...                        Hungary      72       137089
# 14            ...                        England      75       185422
# 15            ...                        Germany      75       183332
# 16            ...                          Italy      75       143076
# 17            ...                         Turkey      75       178600
# 18            ...                          Italy      75       159261
# 19            ...                        Germany      75       195586
# 20            ...                       Slovenia      74       200647
# 21            ...                         Greece      75       203980
# 22            ...                         Mexico      75       153244
# 23            ...                          Spain      75       172287
# 24            ...                       Portugal      75       213516
# 25            ...                    Netherlands      75       199767
# 26            ...                        England      75       186395
# 27            ...                        England      76       231352
# 28            ...                          Spain      76       201893
# 29            ...                       Scotland      74       202539
# ..            ...                            ...     ...          ...
# 100           ...                       Cameroon      71       185090
# 101           ...                        Finland      71       172233
# 102           ...                  United States      75       176237
# 103           ...                        Germany      86       188545
# 104           ...                       Paraguay      74       179752
# 105           ...                          Wales      75       173731
# 106           ...            Republic of Ireland      75       201884
# 107           ...                         Sweden      76       156713
# 108           ...                    Ivory Coast      76       197853
# 109           ...                 Czech Republic      75       201262
# 110           ...                        Austria      77       184200
# 111           ...                        Denmark      78       201943
# 112           ...                         Greece      77       183483
# 113           ...                          Chile      78       181872
# 114           ...                         Russia      76       187491
# 115           ...                         Poland      78       188545
# 116           ...                    Switzerland      78       161805
# 117           ...                       Colombia      79       198710
# 118           ...                        Uruguay      80       179813
# 119           ...                        England      82       202126
# 120           ...                         Turkey      78       124607
# 121           ...                    Netherlands      80       226537
# 122           ...                      Argentina      82       158023
# 123           ...                          Italy      83       192387
# 124           ...                       Portugal      83        20801
# 125           ...                         France      84       194765
# 126           ...                        Belgium      84       183277
# 127           ...                        Germany      85       189596
# 128           ...                         Mexico      78       178224
# 129           ...                         Brazil      84       190871
#
#      Right corner ID  Rival team ID  Short free kick ID  \
# 0             168542           1343              193747
# 1             209331         111099              209331
# 2             182521            241               20801
# 3             191053         111109              191053
# 4             167905         111108              187457
# 5             210951         111459              210951
# 6             209281         111130              168883
# 7             151508           1355              151508
# 8             194958         111473              194958
# 9             191076           1331              184484
# 10            225139         111130              225139
# 11            187043           1363              187043
# 12            211061           1886              211061
# 13            182879           1356              182879
# 14            169638             17              189446
# 15            173474             28              173474
# 16            143076            190              143076
# 17            189491            326              143121
# 18            201508         110556              201508
# 19            137351             21              137351
# 20            200647           1343              200647
# 21            239106           1884              203980
# 22            206655           1032              164079
# 23            199416            448              199416
# 24            188086           1887              188086
# 25            229636            245              204366
# 26            189165            106              186395
# 27            202491           1961              202491
# 28            222943            481              216468
# 29            188166           1318              202539
# ..               ...            ...                 ...
# 100           185090         111112              175896
# 101           172233           1363              172233
# 102           227796           1386              176237
# 103           212622             22              197445
# 104           220334           1369              179752
# 105           186561           1318              173731
# 106           201884           1318              201884
# 107           212678           1331              208448
# 108           226060           1395              188768
# 109           226592           1337              226592
# 110           197445           1337              197445
# 111           190460           1363              190460
# 112           203980           1365              203980
# 113           184941         111108              184941
# 114           147621           1353              147621
# 115           177922           1337              188545
# 116           193348           1322              193348
# 117           198710           1369              198710
# 118           170664           1369              176580
# 119           231677           1337              231677
# 120           124607           1338              124607
# 121           190815           1337              208808
# 122           158023           1370              158023
# 123           173221           1335              173221
# 124           212814           1362               20801
# 125           194765           1343              194765
# 126           192985         105035              192985
# 127           176635           1318              182521
# 128           226045           1387              171897
# 129           190871           1369              190871
#
#      Starting 11 average age  Team ID  Transfer budget €  \
# 0                      27.82     1362                NaN
# 1                      28.27   111130                NaN
# 2                      28.00      243         99800000.0
# 3                      23.09   111487                NaN
# 4                      27.09   111465                NaN
# 5                      26.64   111108                NaN
# 6                      28.91   111114                NaN
# 7                      30.09   110081                NaN
# 8                      27.09     1415                NaN
# 9                      29.27     1341                NaN
# 10                     28.36   111099                NaN
# 11                     24.18     1352                NaN
# 12                     26.73     1356                NaN
# 13                     28.09     1886                NaN
# 14                     27.82     1943         41300000.0
# 15                     26.27       38          7000000.0
# 16                     25.45       39          8000000.0
# 17                     29.09      436         12500000.0
# 18                     28.09     1837         14000000.0
# 19                     26.64   100409          9500000.0
# 20                     27.27     1361                NaN
# 21                     26.91      280         15000000.0
# 22                     28.91     1970         18000000.0
# 23                     25.45      463          4400000.0
# 24                     24.73     1896          8500000.0
# 25                     23.45      247         15000000.0
# 26                     25.00       13         34100000.0
# 27                     25.36     1960         45000000.0
# 28                     27.18      573          9400000.0
# 29                     28.64     1359                NaN
# ..                       ...      ...                ...
# 100                    25.45     1395                NaN
# 101                    26.09     1334                NaN
# 102                    26.91     1387                NaN
# 103                    26.55       21         90000000.0
# 104                    27.00     1375                NaN
# 105                    27.82     1367                NaN
# 106                    27.27     1355                NaN
# 107                    27.09     1363                NaN
# 108                    23.82   111112                NaN
# 109                    24.91     1330                NaN
# 110                    26.09     1322                NaN
# 111                    26.27     1331                NaN
# 112                    26.82     1338                NaN
# 113                    30.45   111459                NaN
# 114                    27.91     1357                NaN
# 115                    28.09     1353                NaN
# 116                    27.45     1364                NaN
# 117                    27.64   111109                NaN
# 118                    26.45     1377                NaN
# 119                    24.91     1318                NaN
# 120                    26.91     1365                NaN
# 121                    25.64   105035                NaN
# 122                    29.18     1369                NaN
# 123                    29.09     1343                NaN
# 124                    28.00     1354                NaN
# 125                    25.09     1335                NaN
# 126                    26.91     1325                NaN
# 127                    27.45     1337                NaN
# 128                    28.27     1386                NaN
# 129                    26.73     1370                NaN
#
#      Whole team average age
# 0                     27.61
# 1                     27.65
# 2                     23.93
# 3                     23.78
# 4                     25.65
# 5                     25.17
# 6                     28.13
# 7                     28.83
# 8                     26.35
# 9                     27.78
# 10                    27.22
# 11                    24.83
# 12                    26.52
# 13                    27.52
# 14                    24.79
# 15                    25.54
# 16                    24.11
# 17                    26.30
# 18                    25.41
# 19                    25.33
# 20                    27.26
# 21                    25.89
# 22                    26.73
# 23                    24.00
# 24                    23.97
# 25                    21.96
# 26                    23.97
# 27                    25.30
# 28                    24.27
# 29                    28.00
# ..                      ...
# 100                   24.61
# 101                   26.22
# 102                   27.48
# 103                   25.36
# 104                   27.78
# 105                   26.48
# 106                   29.17
# 107                   26.57
# 108                   24.96
# 109                   25.35
# 110                   25.35
# 111                   26.04
# 112                   26.65
# 113                   28.57
# 114                   28.00
# 115                   27.09
# 116                   26.87
# 117                   27.74
# 118                   27.70
# 119                   25.57
# 120                   26.22
# 121                   25.43
# 122                   27.87
# 123                   26.65
# 124                   27.91
# 125                   25.65
# 126                   26.52
# 127                   25.52
# 128                   27.17
# 129                   27.35
#
# [130 rows x 22 columns]
